# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `/media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT_test`

# %%
using Revise
using GlauberPT
# Out:
# ERROR: LoadError:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ArgumentError: Package GlauberPT does not have LogarithmicNumbers in its dependencies:
# - You may have a partially installed environment. Try `Pkg.instantiate()`
#   to ensure all packages in the environment are installed.
# - Or, if you have GlauberPT checked out for development and have
#   added LogarithmicNumbers as a dependency but haven't updated your primary
#   environment's manifest file, try `Pkg.resolve()`.
# - Otherwise you may need to report an issue with GlauberPT
# Stacktrace:
#   [1] macro expansion
#     @ ./loading.jl:2403 [inlined]
#   [2] macro expansion
#     @ ./lock.jl:376 [inlined]
#   [3] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2383
#   [4] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2359
#   [5] top-level scope
# ...

# %%
initialize_observable_accumulators(4)
# Out:
# MethodError: no method matching initialize_observable_accumulators(::Int64)
#
# The function `initialize_observable_accumulators` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   initialize_observable_accumulators(::Any, !Matched::Any, !Matched::Any, !Matched::Any, !Matched::Any)
#
#    @ GlauberPT /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT.jl/src/monte_carlo_efficient/observables.jl:35
#
#
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT_test/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:1
